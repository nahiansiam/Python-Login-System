# %%
attempts = 5

while attempts > 0:
    print("\n🔐 ===== Python Secure Login Portal ===== 🔐")

    user_name = input("👤 Username : ")
    user_pass = input("🔑 Password : ")

    if user_name == "Admin" and user_pass == "12345":
        print("\n🎉 Access Granted!")
        print("🚀 Welcome back, Admin.")
        break

    attempts -= 1

    print("\n⚠️ Login Failed!")

    if attempts > 0:
        print(f"🔄 Remaining Attempts : {attempts}")
    else:
        print("🚫 Security Lock Activated!")
        print("🔒 Too many failed attempts.")
# Out:
# 🔐 ===== Python Secure Login Portal ===== 🔐
#
# 🎉 Access Granted!
# 🚀 Welcome back, Admin.
